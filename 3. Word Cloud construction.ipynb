# %%
# this notebook is run on colab. it will misbehave on jupyter notebook while constructing word cloud.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle as pkl

# %%
df = pd.read_pickle('/content/cleaned_df.pkl')

# %%
df
# Out:
#               clothing_ID  Age  \
# original_ind
# 0                     767   33
# 1                    1080   34
# 2                    1077   60
# 3                    1049   50
# 4                     847   47
# ...                   ...  ...
# 23481                1104   34
# 23482                 862   48
# 23483                1104   31
# 23484                1084   28
# 23485                1104   52
#
#                                                           Title  \
# original_ind
# 0                                                           NaN
# 1                                                           NaN
# 2                                       some major design flaws
# 3                                              my favorite buy
# 4                                              flattering shirt
# ...                                                         ...
# 23481                            great dress for many occasions
# ...

# %%
# First form word clouds for the comments in the dataset.

# %%
# Positive comments

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
mask = df.Positively_rated == 1
text = " ".join(review for review in df[mask].Text)
stopwords = set(STOPWORDS)

# Create and generate a word cloud image:
# font_path = r'C:/Windows/Fonts/arialbd.ttf'  # Updated font path
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=300, background_color="white", colormap='magma').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# negative comments

# %%
mask = df.Positively_rated == 0
text = " ".join(review for review in df[mask].Text)
stopwords = set(STOPWORDS)

# Create and generate a word cloud image:
# font_path = r'C:/Windows/Fonts/arialbd.ttf'  # Updated font path
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=300, background_color="white",colormap = 'viridis').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
